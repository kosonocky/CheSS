# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

# %%
# RDKit Atom n:
pen_smiles = [
    "CC1(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)[O-]",
    "C1(C)(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)[O-]",
    "CC1(C)SC2C(NC(=O)Cc3ccccc3)C(=O)N2C1C(=O)[O-]",
    "S1C2C(NC(=O)Cc3ccccc3)C(=O)N2C(C(=O)[O-])C1(C)C",
    "C12SC(C)(C)C(C(=O)[O-])N1C(=O)C2NC(=O)Cc1ccccc1",
    "C1(NC(=O)Cc2ccccc2)C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "N(C(=O)Cc1ccccc1)C1C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "C(=O)(Cc1ccccc1)NC1C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "O=C(Cc1ccccc1)NC1C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "C(C(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)[O-])c1ccccc1",
    "c1(CC(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)[O-])ccccc1",
    "c1ccccc1CC(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "c1cccc(CC(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)[O-])c1",
    "c1ccc(CC(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)[O-])cc1",
    "c1cccc(CC(=O)NC2C(=O)N3C2SC(C)(C)C3C(=O)[O-])c1",
    "c1ccccc1CC(=O)NC1C(=O)N2C1SC(C)(C)C2C(=O)[O-]",
    "C1(=O)C(NC(=O)Cc2ccccc2)C2SC(C)(C)C(C(=O)[O-])N12",
    "O=C1C(NC(=O)Cc2ccccc2)C2SC(C)(C)C(C(=O)[O-])N12",
    "N12C(=O)C(NC(=O)Cc3ccccc3)C1SC(C)(C)C2C(=O)[O-]",
    "C1(C(=O)[O-])N2C(=O)C(NC(=O)Cc3ccccc3)C2SC1(C)C",
    "C(=O)([O-])C1N2C(=O)C(NC(=O)Cc3ccccc3)C2SC1(C)C",
    "O=C([O-])C1N2C(=O)C(NC(=O)Cc3ccccc3)C2SC1(C)C",
    "[O-]C(=O)C1N2C(=O)C(NC(=O)Cc3ccccc3)C2SC1(C)C",
]

nirmatrelvir_smiles = [
    "CC(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "C(C)(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "CC(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "CC(C)(C)C(NC(=O)C(F)(F)F)C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "C(NC(=O)C(F)(F)F)(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "N(C(=O)C(F)(F)F)C(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "C(=O)(NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C)C(F)(F)F",
    "O=C(NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C)C(F)(F)F",
    "C(F)(F)(F)C(=O)NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "FC(F)(F)C(=O)NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "FC(F)(F)C(=O)NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "FC(F)(F)C(=O)NC(C(=O)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C)C(C)(C)C",
    "C(=O)(C(NC(=O)C(F)(F)F)C(C)(C)C)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "O=C(C(NC(=O)C(F)(F)F)C(C)(C)C)N1CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "N1(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)CC2C(C1C(=O)NC(C#N)CC1CCNC1=O)C2(C)C",
    "C1C2C(C(C(=O)NC(C#N)CC3CCNC3=O)N1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C12CN(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C(C(=O)NC(C#N)CC3CCNC3=O)C1C2(C)C",
    "C12C(C(=O)NC(C#N)CC3CCNC3=O)N(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)CC1C2(C)C",
    "C1(C(=O)NC(C#N)CC2CCNC2=O)C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C(=O)(NC(C#N)CC1CCNC1=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "O=C(NC(C#N)CC1CCNC1=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "N(C(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C)C(C#N)CC1CCNC1=O",
    "C(C#N)(CC1CCNC1=O)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C(#N)C(CC1CCNC1=O)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "N#CC(CC1CCNC1=O)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C(C(C#N)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C)C1CCNC1=O",
    "C1(CC(C#N)NC(=O)C2C3C(CN2C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C3(C)C)CCNC1=O",
    "C1CNC(=O)C1CC(C#N)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C1CC(CC(C#N)NC(=O)C2C3C(CN2C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C3(C)C)C(=O)N1",
    "N1CCC(CC(C#N)NC(=O)C2C3C(CN2C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C3(C)C)C1=O",
    "C1(=O)NCCC1CC(C#N)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "O=C1NCCC1CC(C#N)NC(=O)C1C2C(CN1C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C2(C)C",
    "C1(C)(C)C2CN(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C(C(=O)NC(C#N)CC3CCNC3=O)C21",
    "CC1(C)C2CN(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C(C(=O)NC(C#N)CC3CCNC3=O)C21",
    "CC1(C)C2CN(C(=O)C(NC(=O)C(F)(F)F)C(C)(C)C)C(C(=O)NC(C#N)CC3CCNC3=O)C21",
]

azt_smiles = [
    "Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O",
    "c1(C)cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)[nH]c1=O",
    "c1c(C)c(=O)[nH]c(=O)n1C1CC(N=[N+]=[N-])C(CO)O1",
    "n1(C2CC(N=[N+]=[N-])C(CO)O2)cc(C)c(=O)[nH]c1=O",
    "C1(n2cc(C)c(=O)[nH]c2=O)CC(N=[N+]=[N-])C(CO)O1",
    "C1C(N=[N+]=[N-])C(CO)OC1n1cc(C)c(=O)[nH]c1=O",
    "C1(N=[N+]=[N-])CC(n2cc(C)c(=O)[nH]c2=O)OC1CO",
    "N(=[N+]=[N-])C1CC(n2cc(C)c(=O)[nH]c2=O)OC1CO",
    "[N+](=[N-])=NC1CC(n2cc(C)c(=O)[nH]c2=O)OC1CO",
    "[N-]=[N+]=NC1CC(n2cc(C)c(=O)[nH]c2=O)OC1CO",
    "C1(CO)OC(n2cc(C)c(=O)[nH]c2=O)CC1N=[N+]=[N-]",
    "C(O)C1OC(n2cc(C)c(=O)[nH]c2=O)CC1N=[N+]=[N-]",
    "OCC1OC(n2cc(C)c(=O)[nH]c2=O)CC1N=[N+]=[N-]",
    "O1C(CO)C(N=[N+]=[N-])CC1n1cc(C)c(=O)[nH]c1=O",
    "c1(=O)[nH]c(=O)c(C)cn1C1CC(N=[N+]=[N-])C(CO)O1",
    "O=c1[nH]c(=O)c(C)cn1C1CC(N=[N+]=[N-])C(CO)O1",
    "[nH]1c(=O)c(C)cn(C2CC(N=[N+]=[N-])C(CO)O2)c1=O",
    "c1(=O)[nH]c(=O)n(C2CC(N=[N+]=[N-])C(CO)O2)cc1C",
    "O=c1[nH]c(=O)n(C2CC(N=[N+]=[N-])C(CO)O2)cc1C",
]

lsd_smiles = [
    "CCN(CC)C(=O)C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "C(C)N(CC)C(=O)C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "N(CC)(CC)C(=O)C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "C(C)N(CC)C(=O)C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "CCN(CC)C(=O)C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "C(=O)(C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1)N(CC)CC",
    "O=C(C1C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1)N(CC)CC",
    "C1(C(=O)N(CC)CC)C=C2c3cccc4[nH]cc(c34)CC2[NH+](C)C1",
    "C1=C2c3cccc4[nH]cc(c34)CC2[NH+](C)CC1C(=O)N(CC)CC",
    "C12=CC(C(=O)N(CC)CC)C[NH+](C)C1Cc1c[nH]c3cccc2c13",
    "c12cccc3[nH]cc(c13)CC1C2=CC(C(=O)N(CC)CC)C[NH+]1C",
    "c1ccc2[nH]cc3c2c1C1=CC(C(=O)N(CC)CC)C[NH+](C)C1C3",
    "c1cc2c3c(c[nH]c3c1)CC1C2=CC(C(=O)N(CC)CC)C[NH+]1C",
    "c1ccc2c3c(c[nH]c13)CC1C2=CC(C(=O)N(CC)CC)C[NH+]1C",
    "c12cccc3c1c(c[nH]2)CC1C3=CC(C(=O)N(CC)CC)C[NH+]1C",
    "[nH]1cc2c3c(cccc13)C1=CC(C(=O)N(CC)CC)C[NH+](C)C1C2",
    "c1[nH]c2cccc3c2c1CC1C3=CC(C(=O)N(CC)CC)C[NH+]1C",
    "c12c[nH]c3cccc(c13)C1=CC(C(=O)N(CC)CC)C[NH+](C)C1C2",
    "c12c3c[nH]c1cccc2C1=CC(C(=O)N(CC)CC)C[NH+](C)C1C3",
    "C1c2c[nH]c3cccc(c23)C2=CC(C(=O)N(CC)CC)C[NH+](C)C12",
    "C12Cc3c[nH]c4cccc(c34)C1=CC(C(=O)N(CC)CC)C[NH+]2C",
    "[NH+]1(C)CC(C(=O)N(CC)CC)C=C2c3cccc4[nH]cc(c34)CC21",
    "C[NH+]1CC(C(=O)N(CC)CC)C=C2c3cccc4[nH]cc(c34)CC21",
    "C1C(C(=O)N(CC)CC)C=C2c3cccc4[nH]cc(c34)CC2[NH+]1C",
]

fentanyl_smiles = [
    "CCC(=O)N(c1ccccc1)C1CC[NH+](CCc2ccccc2)CC1",
    "C(C)C(=O)N(c1ccccc1)C1CC[NH+](CCc2ccccc2)CC1",
    "C(=O)(CC)N(c1ccccc1)C1CC[NH+](CCc2ccccc2)CC1",
    "O=C(CC)N(c1ccccc1)C1CC[NH+](CCc2ccccc2)CC1",
    "N(C(=O)CC)(c1ccccc1)C1CC[NH+](CCc2ccccc2)CC1",
    "c1(N(C(=O)CC)C2CC[NH+](CCc3ccccc3)CC2)ccccc1",
    "c1ccccc1N(C(=O)CC)C1CC[NH+](CCc2ccccc2)CC1",
    "c1cccc(N(C(=O)CC)C2CC[NH+](CCc3ccccc3)CC2)c1",
    "c1ccc(N(C(=O)CC)C2CC[NH+](CCc3ccccc3)CC2)cc1",
    "c1cccc(N(C(=O)CC)C2CC[NH+](CCc3ccccc3)CC2)c1",
    "c1ccccc1N(C(=O)CC)C1CC[NH+](CCc2ccccc2)CC1",
    "C1(N(C(=O)CC)c2ccccc2)CC[NH+](CCc2ccccc2)CC1",
    "C1C[NH+](CCc2ccccc2)CCC1N(C(=O)CC)c1ccccc1",
    "C1CC(N(C(=O)CC)c2ccccc2)CC[NH+]1CCc1ccccc1",
    "[NH+]1(CCc2ccccc2)CCC(N(C(=O)CC)c2ccccc2)CC1",
    "C(Cc1ccccc1)[NH+]1CCC(N(C(=O)CC)c2ccccc2)CC1",
    "C(C[NH+]1CCC(N(C(=O)CC)c2ccccc2)CC1)c1ccccc1",
    "c1(CC[NH+]2CCC(N(C(=O)CC)c3ccccc3)CC2)ccccc1",
    "c1ccccc1CC[NH+]1CCC(N(C(=O)CC)c2ccccc2)CC1",
    "c1cccc(CC[NH+]2CCC(N(C(=O)CC)c3ccccc3)CC2)c1",
    "c1ccc(CC[NH+]2CCC(N(C(=O)CC)c3ccccc3)CC2)cc1",
    "c1cccc(CC[NH+]2CCC(N(C(=O)CC)c3ccccc3)CC2)c1",
    "c1ccccc1CC[NH+]1CCC(N(C(=O)CC)c2ccccc2)CC1",
    "C1CC(N(C(=O)CC)c2ccccc2)CC[NH+]1CCc1ccccc1",
    "C1C[NH+](CCc2ccccc2)CCC1N(C(=O)CC)c1ccccc1",
]

acid_blue_25_free_acid_smiles = [
    "Nc1c(S(=O)(=O)[O-])cc(Nc2ccccc2)c2c1C(=O)c1ccccc1C2=O",
    "c1(N)c(S(=O)(=O)[O-])cc(Nc2ccccc2)c2c1C(=O)c1ccccc1C2=O",
    "c1(S(=O)(=O)[O-])cc(Nc2ccccc2)c2c(c1N)C(=O)c1ccccc1C2=O",
    "S(=O)(=O)([O-])c1cc(Nc2ccccc2)c2c(c1N)C(=O)c1ccccc1C2=O",
    "O=S(=O)([O-])c1cc(Nc2ccccc2)c2c(c1N)C(=O)c1ccccc1C2=O",
    "O=S(=O)([O-])c1cc(Nc2ccccc2)c2c(c1N)C(=O)c1ccccc1C2=O",
    "[O-]S(=O)(=O)c1cc(Nc2ccccc2)c2c(c1N)C(=O)c1ccccc1C2=O",
    "c1c(Nc2ccccc2)c2c(c(N)c1S(=O)(=O)[O-])C(=O)c1ccccc1C2=O",
    "c1(Nc2ccccc2)cc(S(=O)(=O)[O-])c(N)c2c1C(=O)c1ccccc1C2=O",
    "N(c1ccccc1)c1cc(S(=O)(=O)[O-])c(N)c2c1C(=O)c1ccccc1C2=O",
    "c1(Nc2cc(S(=O)(=O)[O-])c(N)c3c2C(=O)c2ccccc2C3=O)ccccc1",
    "c1ccccc1Nc1cc(S(=O)(=O)[O-])c(N)c2c1C(=O)c1ccccc1C2=O",
    "c1cccc(Nc2cc(S(=O)(=O)[O-])c(N)c3c2C(=O)c2ccccc2C3=O)c1",
    "c1ccc(Nc2cc(S(=O)(=O)[O-])c(N)c3c2C(=O)c2ccccc2C3=O)cc1",
    "c1cccc(Nc2cc(S(=O)(=O)[O-])c(N)c3c2C(=O)c2ccccc2C3=O)c1",
    "c1ccccc1Nc1cc(S(=O)(=O)[O-])c(N)c2c1C(=O)c1ccccc1C2=O",
    "c12c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c1C(=O)c1ccccc1C2=O",
    "c12c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c1C(=O)c1ccccc1C2=O",
    "C1(=O)c2ccccc2C(=O)c2c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c21",
    "O=C1c2ccccc2C(=O)c2c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c21",
    "c12ccccc1C(=O)c1c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c1C2=O",
    "c1cccc2c1C(=O)c1c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c1C2=O",
    "c1ccc2c(c1)C(=O)c1c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c1C2=O",
    "c1ccc2c(c1)C(=O)c1c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c1C2=O",
    "c1cccc2c1C(=O)c1c(Nc3ccccc3)cc(S(=O)(=O)[O-])c(N)c1C2=O",
    "c12ccccc1C(=O)c1c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c1C2=O",
    "C1(=O)c2ccccc2C(=O)c2c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c21",
    "O=C1c2ccccc2C(=O)c2c(N)c(S(=O)(=O)[O-])cc(Nc3ccccc3)c21",
]


avobenzone_smiles = [
    "COc1ccc(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)cc1",
    "O(C)c1ccc(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)cc1",
    "c1(OC)ccc(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)cc1",
    "c1cc(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)ccc1OC",
    "c1cc(OC)ccc1C(=O)CC(=O)c1ccc(C(C)(C)C)cc1",
    "c1(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)ccc(OC)cc1",
    "C(=O)(CC(=O)c1ccc(C(C)(C)C)cc1)c1ccc(OC)cc1",
    "O=C(CC(=O)c1ccc(C(C)(C)C)cc1)c1ccc(OC)cc1",
    "C(C(=O)c1ccc(OC)cc1)C(=O)c1ccc(C(C)(C)C)cc1",
    "C(=O)(CC(=O)c1ccc(OC)cc1)c1ccc(C(C)(C)C)cc1",
    "O=C(CC(=O)c1ccc(OC)cc1)c1ccc(C(C)(C)C)cc1",
    "c1(C(=O)CC(=O)c2ccc(OC)cc2)ccc(C(C)(C)C)cc1",
    "c1cc(C(C)(C)C)ccc1C(=O)CC(=O)c1ccc(OC)cc1",
    "c1cc(C(=O)CC(=O)c2ccc(OC)cc2)ccc1C(C)(C)C",
    "c1(C(C)(C)C)ccc(C(=O)CC(=O)c2ccc(OC)cc2)cc1",
    "C(C)(C)(C)c1ccc(C(=O)CC(=O)c2ccc(OC)cc2)cc1",
    "CC(C)(C)c1ccc(C(=O)CC(=O)c2ccc(OC)cc2)cc1",
    "CC(C)(C)c1ccc(C(=O)CC(=O)c2ccc(OC)cc2)cc1",
    "CC(C)(C)c1ccc(C(=O)CC(=O)c2ccc(OC)cc2)cc1",
    "c1cc(C(=O)CC(=O)c2ccc(OC)cc2)ccc1C(C)(C)C",
    "c1cc(C(C)(C)C)ccc1C(=O)CC(=O)c1ccc(OC)cc1",
    "c1cc(OC)ccc1C(=O)CC(=O)c1ccc(C(C)(C)C)cc1",
    "c1cc(C(=O)CC(=O)c2ccc(C(C)(C)C)cc2)ccc1OC",
]


diphenylaminocarbazole_smiles = [
    "c1ccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)cc1",
    "c1cccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)c1",
    "c1ccccc1N(c1ccccc1)c1ccc2c(c1)[nH]c1ccccc12",
    "c1(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)ccccc1",
    "N(c1ccccc1)(c1ccccc1)c1ccc2c(c1)[nH]c1ccccc12",
    "c1(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)ccccc1",
    "c1ccccc1N(c1ccccc1)c1ccc2c(c1)[nH]c1ccccc12",
    "c1cccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)c1",
    "c1ccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)cc1",
    "c1cccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)c1",
    "c1ccccc1N(c1ccccc1)c1ccc2c(c1)[nH]c1ccccc12",
    "c1(N(c2ccccc2)c2ccccc2)ccc2c(c1)[nH]c1ccccc12",
    "c1cc2c(cc1N(c1ccccc1)c1ccccc1)[nH]c1ccccc12",
    "c1cc(N(c2ccccc2)c2ccccc2)cc2[nH]c3ccccc3c12",
    "c12ccc(N(c3ccccc3)c3ccccc3)cc1[nH]c1ccccc12",
    "c12cc(N(c3ccccc3)c3ccccc3)ccc1c1ccccc1[nH]2",
    "c1c(N(c2ccccc2)c2ccccc2)ccc2c1[nH]c1ccccc12",
    "[nH]1c2ccccc2c2ccc(N(c3ccccc3)c3ccccc3)cc12",
    "c12ccccc1c1ccc(N(c3ccccc3)c3ccccc3)cc1[nH]2",
    "c1cccc2c1[nH]c1cc(N(c3ccccc3)c3ccccc3)ccc12",
    "c1ccc2c(c1)[nH]c1cc(N(c3ccccc3)c3ccccc3)ccc12",
    "c1ccc2[nH]c3cc(N(c4ccccc4)c4ccccc4)ccc3c2c1",
    "c1cccc2[nH]c3cc(N(c4ccccc4)c4ccccc4)ccc3c12",
    "c12ccccc1[nH]c1cc(N(c3ccccc3)c3ccccc3)ccc12",
    "c1ccccc1N(c1ccccc1)c1ccc2c(c1)[nH]c1ccccc12",
    "c1cccc(N(c2ccccc2)c2ccc3c(c2)[nH]c2ccccc23)c1",
]

# %% [markdown]
# Go to featurize_query.py and create feature vector pkl files for all of the above smiles (grouped by the lists they are in).

# %%
df_list = [pd.read_pickle("02_pkl_files/rdkit_n_queries_penicillin.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_nirmatrelvir.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_azt.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_lsd.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_fentanyl.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_acid_blue_25_free_acid.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_avobenzone.pkl"),
            pd.read_pickle("02_pkl_files/rdkit_n_queries_diphenylaminocarbazole.pkl"),
            ]
names_list = [
    "penicillin",
    "nirmatrelvir",
    "azt",
    "lsd",
    "fentanyl",
    "acid_blue_25_free_acid",
    "avobenzone",
    "2-diphenylaminocarbazole",
]
all_smiles_list = [
    pen_smiles,
    nirmatrelvir_smiles,
    azt_smiles,
    lsd_smiles,
    fentanyl_smiles,
    acid_blue_25_free_acid_smiles,
    avobenzone_smiles,
    diphenylaminocarbazole_smiles,
]
for df, name, smiles_list in zip(df_list, names_list, all_smiles_list):
    print(f"\nName: {name}")
    df["features"] = df["features"].apply(lambda x: x/np.linalg.norm(x))
    arr = np.array(df['features'].tolist())
    data = np.dot(arr,arr.T)
    fig, ax = plt.subplots()
    cmap = sns.color_palette("viridis", as_cmap=True)
    ax = sns.heatmap(data, 
                 vmin=0, 
                 vmax=1, 
                 cmap=cmap,
                 cbar_kws={'label': 'Cosine Similarity'},
                 # rotate colorbar title 180
                #  linewidths=0.5
                 square=True,
                 )
    # Set axis labels and force horizontal
    ax.set(xlabel="Atom #", ylabel="Atom #", )

    plt.setp(ax.get_xticklabels(), rotation=0, )
    
    plt.xticks(np.arange(0,len(data),2)+0.5, np.arange(0,len(data),2))
    plt.yticks(np.arange(0,len(data),2)+0.5, np.arange(0,len(data),2))
    plt.setp(ax.get_yticklabels(), rotation=0,)# ha="right",
            # rotation_mode="anchor")

    # Make x axis labels on top
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top')    

        # Make the font size bigger on the annotation in the heatmap
    for text in ax.texts:
        text.set_size(18)
    cbar = ax.collections[0].colorbar
    # cbar.ax.tick_params(labelsize=18)
    cbar.ax.set_ylabel(cbar.ax.get_ylabel(), fontsize=18)
    cbar.ax.yaxis.set_label_coords(5, 0.5)

    # Make the font size bigger on the axis labels
    # ax.tick_params(axis='both', which='major', labelsize=12)
    ax.set_xlabel(ax.get_xlabel(), fontsize=12)
    ax.set_ylabel(ax.get_ylabel(), fontsize=12)
    # ax.xaxis.set_label_coords(0.5, -0.05)
    # ax.yaxis.set_label_coords(-0.05, 0.5)

    
    plt.savefig(f"rdkit_atom_n_fsim_{name}.png", dpi=300, bbox_inches = "tight")
    
    i_max_distance = data[0].argmin()
    print(f"Atom Number {i_max_distance} canonicalization is the most different atom from RDKit Atom 0")
    print(f"SMILES at this index is\n{smiles_list[i_max_distance]}")
